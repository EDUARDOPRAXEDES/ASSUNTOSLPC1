# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUARDOPRAXEDES/ASSUNTOSLPC1/blob/main/Ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = input ("Digite o Numero: ")
print ("O número Informado foi:  ", numero)
# Out:
# Digite o Numero: 1
# O número Informado foi:   1
