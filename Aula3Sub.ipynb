# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUARDOPRAXEDES/ASSUNTOSLPC1/blob/main/Aula3Sub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ETE PORTO DIGITAL 
# DISCIPLINA: LPC1
# PROFESSOR: CLOVES
# ESTUDANTE: PRAXEDES

print ("Olá, ETE PORTO DIGITAL!")
# Out:
# Olá, ETE PORTO DIGITAL!
