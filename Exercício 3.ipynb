# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUARDOPRAXEDES/ASSUNTOSLPC1/blob/main/Exerc%C3%ADcio%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = int(input("Digite o Primeiro Número: "))
numero2 = int(input("Digite o Segundo Número: "))
soma = numero1 + numero2
print("A Soma dos Números é: {}" .format(soma))
# Out:
# Digite o Primeiro Número: 3
# Digite o Segundo Número: 4
# A Soma dos Números é: 7
