# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUARDOPRAXEDES/ASSUNTOSLPC1/blob/main/Desafio%20Estrutura%20de%20Deci%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercicio 01
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
if n1 > n2:
  print(n1, "É maior que ", n2)
elif n2 > n1:
  print(n2, "É maior que ", n1) 

print("Os números são iguais")
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 4
# Os números são iguais

# %%
#Exercicio 02
valor = int(input("Digite o valor: "))
if valor < 0:
  print("O numero é Negativo ")

else:
    print("O número é Positivo")
# Out:
# Digite o valor: 5
# O número é Positivo

# %%
#Execicio 03
sexo = str(input("Digite (F) para Feminino ou (M) Para Masculino: "))
if sexo == "F":
  print("O sexo é Feminino")
else:

    print("O sexo é Masculino")
# Out:
# Digite (F) para Feminino ou (M) Para Masculino: F
# O sexo é Feminino

# %%
#Exercicio 04
letra = input("Digite uma letra: ")
if(letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u"):
  print("A letra é uma Vogal")
  
else:

    print("A letra é uma consoante")
# Out:
# Digite uma letra: H
# A letra é uma consoante

# %%
#Exercicio 05
n1 = int(input("Digite um numero: "))
n2 = int(input("Digite outro numero: "))
n3 = int(input("Digite outro numero: "))
if n1 > n2 and n1 > n3:
  print("O numero maior é: ", n1)
  if n2 > n3 and n2 > n1:
    print("O numero maior é: ", n2)
else:

   print("O numero maior é: ", n3)
# Out:
# Digite um numero: 2
# Digite outro numero: 5
# Digite outro numero: 8
# O numero maior é:  8

# %%
#Exercicio 06
n1 = int(input("Digite um numero: "))
n2 = int(input("Digite outro numero: "))
n3 = int(input("Digite outro numero: "))
if (n1 > n2 and n1 > n3) and (n2 < n1 and n2 < n3):
  print("O numero maior é: ", n1)
  print("O numeor menor é: ", n2)
  if (n2 > n3 and n2 > n1):
    print("O numero maior é: ", n2)
    
else:

   print("O numero maior é: ", n3)
# Out:
# Digite um numero: 6
# Digite outro numero: 2
# Digite outro numero: 4
# O numero maior é:  6
# O numeor menor é:  2

# %%
#exercicio 07
p1 = float(input("Digite o preço do Primeiro produto: "))
p2 = float(input("Digite o preço do Segundo produto: "))
p3 = float(input("Digite o preço do Terceiro produto: "))
if (p1 < p2 and p1 < p3):
  print("Você deve Comprar o ", p1)
if (p2 < p1 and p2 < p3):
    print("Você deve compara o ", p2)
elif (p3 < p1 and p3 < p2):
     print("Voce deve comprar o", p3)
# Out:
# Digite o preço do Primeiro produto: 11.36
# Digite o preço do Segundo produto: 56.98
# Digite o preço do Terceiro produto: 36.88
# Você deve Comprar o  11.36

# %%
#Exercicio 08
n1 = int(input('Escreva um número: '))
n2 = int(input('Escreva um número: '))
n3 = int(input('Escreva um número: '))
t = [n1, n2, n3]
t.sort(reverse = True)
print("A ordem decrescente é :" ,t)
# Out:
# Escreva um número: 87
# Escreva um número: 74
# Escreva um número: 67
# A ordem decrescente é : [87, 74, 67]

# %%
#Exercicio 09
turno = str(input("Digite o turno (M) Matutino, (V) Vespertino, (N) Noturno: "))
if turno == "M":
  print("Matutino. " "Bom Dia!")
elif turno == "V":
  print("Vespertino. " "Boa Tarde!")
elif turno == "N":
  print("Norturno. " "Boa Noite!")
else:
  print("Valor Invalido")
# Out:
# Digite o turno (M) Matutino, (V) Vespertino, (N) Noturno: V
# Vespertino. Boa Tarde!

# %%
#Exercicio 10

# %%
#Exercicio 11

# %%
#Exercicio 12
print("Responda (1) para NÃO ou (2) para SIM")
a = int(input("Telefonou para a vítima? "))
b = int(input("Esteve no local do crime? "))
c = int(input("Mora perto da vítima? "))
d = int(input("Devia para a vítima? "))
e = int(input("Já trabalhou com a vítima? "))
conclui =  (a + b + c + d + e)
if (conclui < 2):
  print("Inocente")
elif (conclui == 2):
  print("Suspeito")
elif (3 <= conclui <= 4):
  print("Cúnplice")
elif (conclui >= 5):
  print("Assasino")
# Out:
# Responda (1) para NÃO ou (2) para SIM
# Telefonou para a vítima? 1
# Esteve no local do crime? 1
# Mora perto da vítima? 1
# Devia para a vítima? 1
# Já trabalhou com a vítima? 1
# Assasino
