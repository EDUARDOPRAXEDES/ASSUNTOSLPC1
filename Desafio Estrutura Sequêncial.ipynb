# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUARDOPRAXEDES/ASSUNTOSLPC1/blob/main/Desafio%20Estrutura%20Sequ%C3%AAncial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercicio 01
print ("Olá, ETE Porto Digital")
# Out:
# Olá, ETE Porto Digital

# %%
# Exercicio 02
numero = input("Digite Um Número: ")
print ("O nomero Informado foi: " , numero)
# Out:
# Digite Um Número: 3
# O nomero Informado foi:  3

# %%
# Exercicio 03
numero1 = int(input("Digite Um Número: "))
numero2 = int(input("Digite Outro Número: "))
soma = numero1 + numero2
print("A Soma dos Números é: {}" .format(soma))
# Out:
# Digite Um Número: 43
# Digite Outro Número: 34
# A Soma dos Números é: 77

# %%
# Exercico 04
nota1 = int(input("Nota 1: "))
nota2 = int(input("Nota 2: "))
nota3 = int(input("Nota 3: "))
nota4 = int(input("Nota 4: "))
media = (nota1 + nota2 + nota3 + nota4) /4
print("A média foi: {}" .format(media))
# Out:
# Nota 1: 5
# Nota 2: 4
# Nota 3: 6
# Nota 4: 8
# A média foi: 5.75

# %%
# Exercicio 05
medida1 = float(input("Insira medida em Metros: "))
convert = (medida1 * 100)
print("A conversão de Metros para Centimetros é: {}" .format(convert))
# Out:
# Insira medida em Metros: 50
# A conversão de Metros para Centimetros é: 5000.0

# %%
# Exercicio 06
diametro = int(input("Insira o Diametro: "))
raio = (diametro / 2)
print("O raio é de: {}" .format(raio))
# Out:
# Insira o Diametro: 400
# O raio é de: 200.0

# %%
# Exercicio 07
base = int(input("Informe a Medidad da Base: "))
altura = int(input("Informe a medida da Altura"))
area = (base * altura)
print("A área é de: {}" .format(area * 2))
# Out:
# Informe a Medidad da Base: 4
# Informe a medida da Altura4
# A área é de: 32

# %%
# Exercicio 08
hora = float(input("Quanto você Ganha por hora: "))
horas = float(input("Quantas Horas Você Trabalha No Mês: "))

# %%
# Exercicio 09
graus = float(input("Insira a Temperatura °F: "))
change = ( 5 * ((graus-32)/9))
print("A Temperatura em Graus Celsius é: {}" .format(change))
# Out:
# Insira a Temperatura °F: 90
# A Temperatura em Graus Celsius é: 32.22222222222222

# %%
# Exercicio 10
graus = float(input("Insira a Temperatura °C: "))
change = (5 / ((graus+32)*9))
print("A Temperatura em Graus Celsius é: {}" .format(change))
# Out:
# Insira a Temperatura °C: 32.2
# A Temperatura em Graus Celsius é: 0.008653513326410522

# %%
# Exercicio 11
n1 = float(input("Insira um Numero Inteiro: "))
n2 = float(input("Insira um Numero Inteiro: "))
real = float(input("Insira um Numero Real: "))
real1 = n1*2*(n2/2)
print("O produto do dobro do primeiro com metade do segundo: ",real1)
real2 = n1*3+real
print("A soma do triplo do primeiro com o terceiro: ", real2)
real3 = real**3
print("O terceiro elevado ao cubo é: ", real3)
# Out:
# Insira um Numero Inteiro: 6
# Insira um Numero Inteiro: 6
# Insira um Numero Real: 5.6
# O produto do dobro do primeiro com metade do segundo:  36.0
# A soma do triplo do primeiro com o terceiro:  23.6
# O terceiro elevado ao cubo é:  175.61599999999996

# %%
# Exercicio 12
altura = float(input("Insira Sua Altura: "))
peso = ((72.7*altura)-58)
print("O Peso Idel É: {}" .format(peso))
# Out:
# Insira Sua Altura: 1.86
# O Peso Idel É: 77.22200000000001

# %%
# Exercicio 13
sexo = int(input("Digite seu Sexo: (1) Para Homem (2) Para Mulher: "))
altura = float(input("Digite sua altura: "))
peso = float(input("Digite seu peso: "))
peso1 = (72.7*altura) - 58
peso2 = (62.1*altura) - 44.7

if sexo == 1:
  print("Seu peso ideal é: ", peso1)
if sexo ==2:
  print("Seu peso ideal é: ", peso2)
# Out:
# Digite seu Sexo: (1) Para Homem (2) Para Mulher: 1
# Digite sua altura: 1.86
# Digite seu peso: 95
# Seu peso ideal é:  77.22200000000001

# %%
# Exercicio 14
peso = float(input("Digite o Peso: "))
if peso >50:
  excesso = peso - 50
  multa = excesso * 4
else:
  excesso = "ZERO"
  multa = "ZERO"
print("O excesso de peso foi de: ", str(excesso), "Kg, Portanto,  multa é de R$ , ", str(multa))
# Out:
# Digite o Peso: 55
# O excesso de peso foi de:  5.0 Kg, Portanto,  multa é de R$ ,  20.0

# %%
# Exercico 15
tamanho = float(input("Qual o Tamanha do Arquivo em MB: "))
velocidade = float(input("Qual a Velocidade do Link: "))
tempo = (tamanho / velocidade /8)
print("O tempo é de: {}" .format(tempo))
# Out:
# Qual o Tamanha do Arquivo em MB: 10
# Qual a Velocidade do Link: 20
# O tempo é de: 0.0625
